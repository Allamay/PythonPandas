# %% [markdown]
# Markdown should be selected for notes or reference...
# a. select from drop down button ( default as code, select Markdown)...
# b. Or keyboard shortcut "ESC + M"...
# To run it, keyboard short cut "SHIFT + ENTER"...

# %% [markdown]
# Keyboard shortcut...
# Help/select Keyboard shortcut...

# %% [markdown]
# Insert rows in Jupyter
# a. ESC + B = insert empty row below the current row
# b. ESC + A = insert empty row above the current row

# %% [markdown]
# Importing Pandas

# %% [markdown]
# Import pandas as pd -- This will be an error, caused by capitalized word

# %%
import pandas as pd

# %% [markdown]
# Panda functions can be quickly opened by typing pd.<tab>
# To get PD docs summary, just type PD?

# %%
pd?

# %%
pd.read_csv?

# %%
pd.show_versions?

# %% [markdown]
# FUNCTION TO SHOW VERSIONS

# %% [markdown]
# *** dont forget s after function, it is always functions.

# %% [markdown]
# a. Full version use show_versions()

# %%
pd.show_versions()
# Out:
# INSTALLED VERSIONS
# ------------------
# commit           : 2cb96529396d93b46abab7bbc73a208e708c642e
# python           : 3.8.8.final.0
# python-bits      : 64
# OS               : Windows
# OS-release       : 10
# Version          : 10.0.18362
# machine          : AMD64
# processor        : Intel64 Family 6 Model 58 Stepping 9, GenuineIntel
# byteorder        : little
# LC_ALL           : None
# LANG             : None
# LOCALE           : English_United States.1252
#
# pandas           : 1.2.4
# numpy            : 1.20.1
# pytz             : 2021.1
# dateutil         : 2.8.1
# pip              : 21.0.1
# setuptools       : 52.0.0.post20210125
# Cython           : 0.29.23
# pytest           : 6.2.3
# hypothesis       : None
# sphinx           : 4.0.1
# blosc            : None
# feather          : None
# xlsxwriter       : 1.3.8
# lxml.etree       : 4.6.3
# html5lib         : 1.1
# pymysql          : None
# psycopg2         : None
# jinja2           : 2.11.3
# ...

# %% [markdown]
# b. short version use __version__

# %%
pd.__version__
# Out:
# '1.2.4'

# %% [markdown]
# Data Frame

# %% [markdown]
# Data Frame is like excel sheet or SQL table...

# %%
oo=pd.read_csv('C:/Users/may/Desktop/data/olympics.csv', skiprows=4)
oo.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %% [markdown]
# ***Read_csv need to change the "\" to "/" for original directory "C:\Users\may\Desktop\data"

# %% [markdown]
# If type oo, will show the first/last 5 rows as default

# %%
oo
# Out:
#           City  Edition      Sport       Discipline               Athlete  \
# 0       Athens     1896   Aquatics         Swimming         HAJOS, Alfred
# 1       Athens     1896   Aquatics         Swimming      HERSCHMANN, Otto
# 2       Athens     1896   Aquatics         Swimming     DRIVAS, Dimitrios
# 3       Athens     1896   Aquatics         Swimming    MALOKINIS, Ioannis
# 4       Athens     1896   Aquatics         Swimming    CHASAPIS, Spiridon
# ...        ...      ...        ...              ...                   ...
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender                       Event Event_gender   Medal
# ...

# %% [markdown]
# Series : kinda a row or a column
# For the column, can use tablename.columnname ( if no space )
# or tablename[""] or tablename['']
# multible series: tablename[["column1","column2"]] 必须两个中括号， 双引号，单引号都可以
# column 名字的大小写必须跟原来的数据一样， 否则ERROR

# %%
oo["City"]
# Out:
# 0         Athens
# 1         Athens
# 2         Athens
# 3         Athens
# 4         Athens
#           ...
# 29211    Beijing
# 29212    Beijing
# 29213    Beijing
# 29214    Beijing
# 29215    Beijing
# Name: City, Length: 29216, dtype: object

# %%
oo["Athlete"]
# Out:
# 0               HAJOS, Alfred
# 1            HERSCHMANN, Otto
# 2           DRIVAS, Dimitrios
# 3          MALOKINIS, Ioannis
# 4          CHASAPIS, Spiridon
#                  ...
# 29211          ENGLICH, Mirko
# 29212    MIZGAITIS, Mindaugas
# 29213         PATRIKEEV, Yuri
# 29214           LOPEZ, Mijain
# 29215          BAROEV, Khasan
# Name: Athlete, Length: 29216, dtype: object

# %%
oo.Athlete
# Out:
# 0               HAJOS, Alfred
# 1            HERSCHMANN, Otto
# 2           DRIVAS, Dimitrios
# 3          MALOKINIS, Ioannis
# 4          CHASAPIS, Spiridon
#                  ...
# 29211          ENGLICH, Mirko
# 29212    MIZGAITIS, Mindaugas
# 29213         PATRIKEEV, Yuri
# 29214           LOPEZ, Mijain
# 29215          BAROEV, Khasan
# Name: Athlete, Length: 29216, dtype: object

# %%
oo.City
# Out:
# 0         Athens
# 1         Athens
# 2         Athens
# 3         Athens
# 4         Athens
#           ...
# 29211    Beijing
# 29212    Beijing
# 29213    Beijing
# 29214    Beijing
# 29215    Beijing
# Name: City, Length: 29216, dtype: object

# %%
oo[["City","Athlete","Edition"]]
# Out:
#           City               Athlete  Edition
# 0       Athens         HAJOS, Alfred     1896
# 1       Athens      HERSCHMANN, Otto     1896
# 2       Athens     DRIVAS, Dimitrios     1896
# 3       Athens    MALOKINIS, Ioannis     1896
# 4       Athens    CHASAPIS, Spiridon     1896
# ...        ...                   ...      ...
# 29211  Beijing        ENGLICH, Mirko     2008
# 29212  Beijing  MIZGAITIS, Mindaugas     2008
# 29213  Beijing       PATRIKEEV, Yuri     2008
# 29214  Beijing         LOPEZ, Mijain     2008
# 29215  Beijing        BAROEV, Khasan     2008
#
# [29216 rows x 3 columns]

# %% [markdown]
# type() FUNCTION WILL HELP CHECK WHETHER IT IS DATAFRAME OR SERIES

# %%
type(oo)
# Out:
# pandas.core.frame.DataFrame

# %%
type(oo.City)
# Out:
# pandas.core.series.Series

# %%
type(oo[['City','Athlete','Edition']])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# List Olympics DataFrame

# %%
oo
# Out:
#           City  Edition      Sport       Discipline               Athlete  \
# 0       Athens     1896   Aquatics         Swimming         HAJOS, Alfred
# 1       Athens     1896   Aquatics         Swimming      HERSCHMANN, Otto
# 2       Athens     1896   Aquatics         Swimming     DRIVAS, Dimitrios
# 3       Athens     1896   Aquatics         Swimming    MALOKINIS, Ioannis
# 4       Athens     1896   Aquatics         Swimming    CHASAPIS, Spiridon
# ...        ...      ...        ...              ...                   ...
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender                       Event Event_gender   Medal
# ...

# %% [markdown]
# list COLUMN NOC

# %%
oo.NOC
# Out:
# 0        HUN
# 1        AUT
# 2        GRE
# 3        GRE
# 4        GRE
#         ...
# 29211    GER
# 29212    LTU
# 29213    ARM
# 29214    CUB
# 29215    RUS
# Name: NOC, Length: 29216, dtype: object

# %%
oo['NOC']
# Out:
# 0        HUN
# 1        AUT
# 2        GRE
# 3        GRE
# 4        GRE
#         ...
# 29211    GER
# 29212    LTU
# 29213    ARM
# 29214    CUB
# 29215    RUS
# Name: NOC, Length: 29216, dtype: object

# %%
type(oo.NOC)
# Out:
# pandas.core.series.Series

# %%
import pandas as pd

# %%
oo=pd.read_csv("C:/Users/may/Desktop/data/Olympics.csv",skiprows=4)

# %% [markdown]
# Shape function tells you total rows and columns

# %%
oo.shape
# Out:
# (29216, 10)

# %%
If just row or column, can add 0 or 1 [必须中括号]

# %%
oo.shape[0]
# Out:
# 29216

# %%
oo.shape[1]
# Out:
# 10

# %%
oo.head() #前五行 可以自行加入行数
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
oo.tail() #最后五行 可以自行加入行数
# Out:
#           City  Edition      Sport       Discipline               Athlete  \
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender       Event Event_gender   Medal
# 29211  GER    Men   84 - 96kg            M  Silver
# 29212  LTU    Men  96 - 120kg            M  Bronze
# 29213  ARM    Men  96 - 120kg            M  Bronze
# 29214  CUB    Men  96 - 120kg            M    Gold
# 29215  RUS    Men  96 - 120kg            M  Silver

# %%
oo.info() # THIS FUNCITON GIVES DATA TYPES, ALSO MORE INFO THAN SHAPE FUNCTION, IT HELPS CHECK NULL/NON-NULL CELLS
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29216 entries, 0 to 29215
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   City          29216 non-null  object
#  1   Edition       29216 non-null  int64
#  2   Sport         29216 non-null  object
#  3   Discipline    29216 non-null  object
#  4   Athlete       29216 non-null  object
#  5   NOC           29216 non-null  object
#  6   Gender        29216 non-null  object
#  7   Event         29216 non-null  object
#  8   Event_gender  29216 non-null  object
#  9   Medal         29216 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 2.2+ MB

# %% [markdown]
# Value_counts() # Count the unique values, also default would always show result from large to small

# %%
oo.Edition.value_counts()
# Out:
# 2008    2042
# 2000    2015
# 2004    1998
# 1996    1859
# 1992    1705
# 1988    1546
# 1984    1459
# 1980    1387
# 1976    1305
# 1920    1298
# 1972    1185
# 1968    1031
# 1964    1010
# 1952     889
# 1956     885
# 1912     885
# 1924     884
# 1960     882
# 1936     875
# 1948     814
# 1908     804
# 1928     710
# 1932     615
# 1900     512
# 1904     470
# 1896     151
# Name: Edition, dtype: int64

# %%
oo.Gender.value_counts(ascending=True,dropna=False) # Pay attention to True/False's spelling & format
# Out:
# Women     7495
# Men      21721
# Name: Gender, dtype: int64

# %%
oo.Athlete.sort_values(inplace=False) # Inplace defaut as False, 就是问函数是否改变原来的数列
# Out:
# 651                 AABYE, Edgar
# 2849       AALTONEN, Arvo Ossian
# 2852       AALTONEN, Arvo Ossian
# 7716    AALTONEN, Paavo Johannes
# 7730    AALTONEN, Paavo Johannes
#                   ...
# 603                   ÖSTMO, Ole
# 608                   ÖSTMO, Ole
# 621                   ÖSTMO, Ole
# 596                   ÖSTMO, Ole
# 8051           ÖSTRAND, Per-Olof
# Name: Athlete, Length: 29216, dtype: object

# %%
oo.sort_values(by=["Edition",'Athlete'])  # 双引单引可以混用
# Out:
#           City  Edition       Sport    Discipline  \
# 7       Athens     1896    Aquatics      Swimming
# 82      Athens     1896  Gymnastics   Artistic G.
# 110     Athens     1896  Gymnastics   Artistic G.
# 111     Athens     1896  Gymnastics   Artistic G.
# 48      Athens     1896     Cycling  Cycling Road
# ...        ...      ...         ...           ...
# 28095  Beijing     2008  Equestrian      Dressage
# 28819  Beijing     2008     Sailing       Sailing
# 28977  Beijing     2008   Taekwondo     Taekwondo
# 28387  Beijing     2008  Gymnastics   Rhythmic G.
# 29007  Beijing     2008      Tennis        Tennis
#
#                               Athlete  NOC Gender                 Event  \
# 7                    ANDREOU, Joannis  GRE    Men       1200m freestyle
# 82           ANDRIAKOPOULOS, Nicolaos  GRE    Men         rope climbing
# 110          ANDRIAKOPOULOS, Nicolaos  GRE    Men   team, parallel bars
# ...

# %%
oo.Medal=='Gold'
# Out:
# 0         True
# 1        False
# 2        False
# 3         True
# 4        False
#          ...
# 29211    False
# 29212    False
# 29213    False
# 29214     True
# 29215    False
# Name: Medal, Length: 29216, dtype: bool

# %%
oo[oo.Medal=='Gold'] #直接中括号
# Out:
#           City  Edition      Sport       Discipline              Athlete  NOC  \
# 0       Athens     1896   Aquatics         Swimming        HAJOS, Alfred  HUN
# 3       Athens     1896   Aquatics         Swimming   MALOKINIS, Ioannis  GRE
# 6       Athens     1896   Aquatics         Swimming        HAJOS, Alfred  HUN
# 9       Athens     1896   Aquatics         Swimming        NEUMANN, Paul  AUT
# 13      Athens     1896  Athletics        Athletics        BURKE, Thomas  USA
# ...        ...      ...        ...              ...                  ...  ...
# 29199  Beijing     2008  Wrestling  Wrestling Gre-R       GUENOT, Steeve  FRA
# 29203  Beijing     2008  Wrestling  Wrestling Gre-R  KVIRKELIA, Manuchar  GEO
# 29206  Beijing     2008  Wrestling  Wrestling Gre-R     MINGUZZI, Andrea  ITA
# 29210  Beijing     2008  Wrestling  Wrestling Gre-R   KHUSHTOV, Aslanbek  RUS
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R        LOPEZ, Mijain  CUB
#
# ...

# %%
oo[(oo.Medal=='Gold')&(oo.Gender=='Women')] # multi condition
# Out:
#            City  Edition          Sport       Discipline  \
# 417       Paris     1900           Golf             Golf
# 641       Paris     1900         Tennis           Tennis
# 649       Paris     1900         Tennis           Tennis
# 710    St Louis     1904        Archery          Archery
# 713    St Louis     1904        Archery          Archery
# ...         ...      ...            ...              ...
# 29134   Beijing     2008  Weightlifting    Weightlifting
# 29147   Beijing     2008      Wrestling  Wrestling Free.
# 29155   Beijing     2008      Wrestling  Wrestling Free.
# 29163   Beijing     2008      Wrestling  Wrestling Free.
# 29171   Beijing     2008      Wrestling  Wrestling Free.
#
#                      Athlete  NOC Gender  \
# 417    ABBOTT, Margaret Ives  USA  Women
# 641        COOPER, Charlotte  GBR  Women
# 649        COOPER, Charlotte  GBR  Women
# 710    HOWELL, Matilda Scott  USA  Women
# 713    HOWELL, Matilda Scott  USA  Women
# ...

# %%
oo[oo.Athlete.str.contains('Floren*')] # use wild card to search for strings
# Out:
#                         City  Edition       Sport      Discipline  \
# 1843                  London     1908     Skating  Figure skating
# 1848                  London     1908     Skating  Figure skating
# 4173                   Paris     1924    Aquatics        Swimming
# 8162                Helsinki     1952   Athletics       Athletics
# 9060   Melbourne / Stockholm     1956   Athletics       Athletics
# 10849                  Tokyo     1964   Athletics       Athletics
# 16817            Los Angeles     1984   Athletics       Athletics
# 16905            Los Angeles     1984   Athletics       Athletics
# 18287                  Seoul     1988   Athletics       Athletics
# 18305                  Seoul     1988   Athletics       Athletics
# 18347                  Seoul     1988   Athletics       Athletics
# 18374                  Seoul     1988   Athletics       Athletics
# 22571                Atlanta     1996      Hockey          Hockey
# ...

# %%
jo=oo[oo.Athlete == 'OWENS, Jesse']
jo
# Out:
#         City  Edition      Sport Discipline       Athlete  NOC Gender  \
# 6427  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
# 6439  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
# 6456  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
# 6523  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
#
#              Event Event_gender Medal
# 6427          100m            M  Gold
# 6439          200m            M  Gold
# 6456  4x100m relay            M  Gold
# 6523     long jump            M  Gold

# %%
jo.Event.value_counts()
# Out:
# 100m            1
# 200m            1
# 4x100m relay    1
# long jump       1
# Name: Event, dtype: int64

# %%
gbm=oo[(oo.Gender=="Men")&(oo.Medal=="Gold")&(oo.Sport=="Badminton")]

# %%
gbm.sort_values(by='Athlete')
# Out:
#             City  Edition      Sport Discipline                  Athlete  NOC  \
# 20045  Barcelona     1992  Badminton  Badminton        BUDI KUSUMA, Alan  INA
# 23701     Sydney     2000  Badminton  Badminton            GUNAWAN, Tony  INA
# 25718     Athens     2004  Badminton  Badminton             HA, Tae-Kwon  KOR
# 25734     Athens     2004  Badminton  Badminton          HIDAYAT, Taufik  INA
# 21787    Atlanta     1996  Badminton  Badminton  HOYER-LARSEN, Poul Erik  DEN
# 23717     Sydney     2000  Badminton  Badminton              JI, Xinpeng  CHN
# 27725    Beijing     2008  Badminton  Badminton             KIDO, Markis  INA
# 25719     Athens     2004  Badminton  Badminton           KIM, Dong Moon  KOR
# 21773    Atlanta     1996  Badminton  Badminton           KIM, Dong Moon  KOR
# 20031  Barcelona     1992  Badminton  Badminton            KIM, Moon-Soo  KOR
# 27727    Beijing     2008  Badminton  Badminton             LEE, Yongdae  KOR
# ...

# %%
rec=oo[oo.Edition>=1984]

# %%
rec.NOC.value_counts()
# Out:
# USA    1837
# AUS     762
# GER     691
# CHN     679
# RUS     638
#        ...
# SUD       1
# URU       1
# DJI       1
# AHO       1
# CIV       1
# Name: NOC, Length: 124, dtype: int64

# %%
gmh=oo[(oo.Gender=="Men")&(oo.Medal=="Gold")&(oo.Event=="100m")]

# %%
gmh.sort_values('Edition',ascending=False)[['City','Edition','Athlete','NOC']]
# Out:
#                         City  Edition                Athlete  NOC
# 27552                Beijing     2008            BOLT, Usain  JAM
# 25539                 Athens     2004         GATLIN, Justin  USA
# 23521                 Sydney     2000        GREENE, Maurice  USA
# 21598                Atlanta     1996        BAILEY, Donovan  CAN
# 19859              Barcelona     1992      CHRISTIE, Linford  GBR
# 18284                  Seoul     1988            LEWIS, Carl  USA
# 16794            Los Angeles     1984            LEWIS, Carl  USA
# 15374                 Moscow     1980           WELLS, Allan  GBR
# 14069               Montreal     1976       CRAWFORD, Hasely  TRI
# 12902                 Munich     1972         BORZOV, Valery  URS
# 11865                 Mexico     1968       HINES, James Ray  USA
# 10823                  Tokyo     1964          HAYES, Robert  USA
# 9924                    Rome     1960            HARY, Armin  EUA
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline # Defaut is line or use plot(kind='line' - bar/barth/pie)

# %%
Fo=oo[oo.Edition==1896]

# %%
Fo.Sport.value_counts().plot()
# Out:
# <AxesSubplot:>

# %%
Fo.Sport.value_counts().plot(kind='bar');

# %%
Fo.Sport.value_counts().plot(kind='bar') # 有没有分号图表结果一样。唯一不同，没有分号，图上方多一条注释而已
# Out:
# <AxesSubplot:>

# %%
Fo.Sport.value_counts().plot(kind='barh');

# %%
Fo.Sport.value_counts().plot(kind='pie');

# %%
Fo.Sport.value_counts().plot(kind='bar',color='red'); # color info can be found in the matplotlob website

# %%
Fo.Sport.value_counts().plot()
# Out:
# <AxesSubplot:>

# %%
Fo.Sport.value_counts().plot(figsize=(10,3))  # 可以变换图形大小，从而解决注释overlap的问题
# Out:
# <AxesSubplot:>

# %%
Fo.Sport.value_counts().plot(kind='pie',colormap='Pastel1') 
#COLORMAP 3 color types: a渐层， b中间渐层 c各种颜色 对应选择一个合适的
# Out:
# <AxesSubplot:ylabel='Sport'>

# %%
import seaborn as sb
sb.countplot(x='Medal',data=oo, hue="Gender")
# Out:
# <AxesSubplot:xlabel='Medal', ylabel='count'>

# %%
cn2008=oo[(oo.Edition==2008)&(oo.NOC=='CHN')]

# %%
cn2008.Gender.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sb.countplot(data=cn2008,x='Gender',palette='bwr') #data 后面不用任何标点
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
sb.countplot(data=cn2008,x='Medal',hue='Gender',palette='bwr',order=['Gold','Silver','Bronze'])
# Out:
# <AxesSubplot:xlabel='Medal', ylabel='count'>

# %%
type(oo.index) # We cannot change index number to another squence number
# Out:
# pandas.core.indexes.range.RangeIndex

# %%
oo.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
oo.set_index('Athlete')
# Out:
#                       level_0  index     City  Edition      Sport  \
# Athlete
# HAJOS, Alfred               0      0   Athens     1896   Aquatics
# HERSCHMANN, Otto            1      1   Athens     1896   Aquatics
# DRIVAS, Dimitrios           2      2   Athens     1896   Aquatics
# MALOKINIS, Ioannis          3      3   Athens     1896   Aquatics
# CHASAPIS, Spiridon          4      4   Athens     1896   Aquatics
# ...                       ...    ...      ...      ...        ...
# ENGLICH, Mirko          29211  29211  Beijing     2008  Wrestling
# MIZGAITIS, Mindaugas    29212  29212  Beijing     2008  Wrestling
# PATRIKEEV, Yuri         29213  29213  Beijing     2008  Wrestling
# LOPEZ, Mijain           29214  29214  Beijing     2008  Wrestling
# BAROEV, Khasan          29215  29215  Beijing     2008  Wrestling
#
#                            Discipline  NOC Gender                       Event  \
# Athlete
# ...

# %%
oo.head()
# Out:
#    level_0  index             Athlete    City  Edition     Sport Discipline  \
# 0        0      0       HAJOS, Alfred  Athens     1896  Aquatics   Swimming
# 1        1      1    HERSCHMANN, Otto  Athens     1896  Aquatics   Swimming
# 2        2      2   DRIVAS, Dimitrios  Athens     1896  Aquatics   Swimming
# 3        3      3  MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming
# 4        4      4  CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming
#
#    NOC Gender                       Event Event_gender   Medal
# 0  HUN    Men              100m freestyle            M    Gold
# 1  AUT    Men              100m freestyle            M  Silver
# 2  GRE    Men  100m freestyle for sailors            M  Bronze
# 3  GRE    Men  100m freestyle for sailors            M    Gold
# 4  GRE    Men  100m freestyle for sailors            M  Silver

# %%
oo.head()
# Out:
#    level_0  index             Athlete    City  Edition     Sport Discipline  \
# 0        0      0       HAJOS, Alfred  Athens     1896  Aquatics   Swimming
# 1        1      1    HERSCHMANN, Otto  Athens     1896  Aquatics   Swimming
# 2        2      2   DRIVAS, Dimitrios  Athens     1896  Aquatics   Swimming
# 3        3      3  MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming
# 4        4      4  CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming
#
#    NOC Gender                       Event Event_gender   Medal
# 0  HUN    Men              100m freestyle            M    Gold
# 1  AUT    Men              100m freestyle            M  Silver
# 2  GRE    Men  100m freestyle for sailors            M  Bronze
# 3  GRE    Men  100m freestyle for sailors            M    Gold
# 4  GRE    Men  100m freestyle for sailors            M  Silver

# %%
oo.head()
# Out:
#    level_0  index             Athlete    City  Edition     Sport Discipline  \
# 0        0      0       HAJOS, Alfred  Athens     1896  Aquatics   Swimming
# 1        1      1    HERSCHMANN, Otto  Athens     1896  Aquatics   Swimming
# 2        2      2   DRIVAS, Dimitrios  Athens     1896  Aquatics   Swimming
# 3        3      3  MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming
# 4        4      4  CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming
#
#    NOC Gender                       Event Event_gender   Medal
# 0  HUN    Men              100m freestyle            M    Gold
# 1  AUT    Men              100m freestyle            M  Silver
# 2  GRE    Men  100m freestyle for sailors            M  Bronze
# 3  GRE    Men  100m freestyle for sailors            M    Gold
# 4  GRE    Men  100m freestyle for sailors            M  Silver

# %%
oo.head()
# Out:
#    level_0  index             Athlete    City  Edition     Sport Discipline  \
# 0        0      0       HAJOS, Alfred  Athens     1896  Aquatics   Swimming
# 1        1      1    HERSCHMANN, Otto  Athens     1896  Aquatics   Swimming
# 2        2      2   DRIVAS, Dimitrios  Athens     1896  Aquatics   Swimming
# 3        3      3  MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming
# 4        4      4  CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming
#
#    NOC Gender                       Event Event_gender   Medal
# 0  HUN    Men              100m freestyle            M    Gold
# 1  AUT    Men              100m freestyle            M  Silver
# 2  GRE    Men  100m freestyle for sailors            M  Bronze
# 3  GRE    Men  100m freestyle for sailors            M    Gold
# 4  GRE    Men  100m freestyle for sailors            M  Silver

# %%
oo.head()
# Out:
#                     level_0  index    City  Edition     Sport Discipline  NOC  \
# Athlete
# HAJOS, Alfred             0      0  Athens     1896  Aquatics   Swimming  HUN
# HERSCHMANN, Otto          1      1  Athens     1896  Aquatics   Swimming  AUT
# DRIVAS, Dimitrios         2      2  Athens     1896  Aquatics   Swimming  GRE
# MALOKINIS, Ioannis        3      3  Athens     1896  Aquatics   Swimming  GRE
# CHASAPIS, Spiridon        4      4  Athens     1896  Aquatics   Swimming  GRE
#
#                    Gender                       Event Event_gender   Medal
# Athlete
# HAJOS, Alfred         Men              100m freestyle            M    Gold
# HERSCHMANN, Otto      Men              100m freestyle            M  Silver
# DRIVAS, Dimitrios     Men  100m freestyle for sailors            M  Bronze
# MALOKINIS, Ioannis    Men  100m freestyle for sailors            M    Gold
# CHASAPIS, Spiridon    Men  100m freestyle for sailors            M  Silver

# %%
oo.loc['HAJOS, Alfred']
# Out:
#                level_0  index    City  Edition     Sport Discipline  NOC  \
# Athlete
# HAJOS, Alfred        0      0  Athens     1896  Aquatics   Swimming  HUN
# HAJOS, Alfred        6      6  Athens     1896  Aquatics   Swimming  HUN
#
#               Gender            Event Event_gender Medal
# Athlete
# HAJOS, Alfred    Men   100m freestyle            M  Gold
# HAJOS, Alfred    Men  1200m freestyle            M  Gold

# %%
oo.iloc[1700] # find index # 1700 record
# Out:
# level_0            1700
# index              1700
# City             London
# Edition            1908
# Sport           Sailing
# Discipline      Sailing
# NOC                 FRA
# Gender              Men
# Event                6m
# Event_gender          X
# Medal            Bronze
# Name: RABOT, Pierre, dtype: object

# %%
oo.iloc[[1700,120,1500]] # show multi index records
# Out:
#                  level_0  index    City  Edition       Sport   Discipline  \
# Athlete
# RABOT, Pierre       1700   1700  London     1908     Sailing      Sailing
# NIELSEN, Holger      120    120  Athens     1896    Shooting     Shooting
# LEFDAHL, Rolf       1500   1500  London     1908  Gymnastics  Artistic G.
#
#                  NOC Gender                             Event Event_gender  \
# Athlete
# RABOT, Pierre    FRA    Men                                6m            X
# NIELSEN, Holger  DEN    Men  25m rapid fire pistol (60 shots)            M
# LEFDAHL, Rolf    NOR    Men                  team competition            M
#
#                   Medal
# Athlete
# RABOT, Pierre    Bronze
# NIELSEN, Holger  Bronze
# LEFDAHL, Rolf    Silver

# %%
oo.iloc[1:4]  #显示 record 1-4
# Out:
#                     level_0  index    City  Edition     Sport Discipline  NOC  \
# Athlete
# HERSCHMANN, Otto          1      1  Athens     1896  Aquatics   Swimming  AUT
# DRIVAS, Dimitrios         2      2  Athens     1896  Aquatics   Swimming  GRE
# MALOKINIS, Ioannis        3      3  Athens     1896  Aquatics   Swimming  GRE
#
#                    Gender                       Event Event_gender   Medal
# Athlete
# HERSCHMANN, Otto      Men              100m freestyle            M  Silver
# DRIVAS, Dimitrios     Men  100m freestyle for sailors            M  Bronze
# MALOKINIS, Ioannis    Men  100m freestyle for sailors            M    Gold

# %%
oo.Edition.value_counts().sort_index().plot()
# Out:
# <AxesSubplot:>

# %%
oo[oo.Edition==2008]
# Out:
#                       level_0  index     City  Edition      Sport  \
# Athlete
# GALPERIN, Gleb          27174  27174  Beijing     2008   Aquatics
# MITCHAM, Matthew        27175  27175  Beijing     2008   Aquatics
# ZHOU, Luxin             27176  27176  Beijing     2008   Aquatics
# WANG, Xin               27177  27177  Beijing     2008   Aquatics
# CHEN, Ruolin            27178  27178  Beijing     2008   Aquatics
# ...                       ...    ...      ...      ...        ...
# ENGLICH, Mirko          29211  29211  Beijing     2008  Wrestling
# MIZGAITIS, Mindaugas    29212  29212  Beijing     2008  Wrestling
# PATRIKEEV, Yuri         29213  29213  Beijing     2008  Wrestling
# LOPEZ, Mijain           29214  29214  Beijing     2008  Wrestling
# BAROEV, Khasan          29215  29215  Beijing     2008  Wrestling
#
#                            Discipline  NOC Gender         Event Event_gender  \
# Athlete
# ...

# %%
O2008=oo[oo.Edition==2008]

# %%
noc=pd.read_csv('C:/Users/may/Desktop/data/country.csv')

# %%
oo.groupby ('Edition')

# %%
type(oo.groupby ('Edition'))
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
list(oo.groupby ('Edition'))
# Out:
# [(1896,
#                             level_0  index    City  Edition          Sport  \
#   Athlete
#   HAJOS, Alfred                   0      0  Athens     1896       Aquatics
#   HERSCHMANN, Otto                1      1  Athens     1896       Aquatics
#   DRIVAS, Dimitrios               2      2  Athens     1896       Aquatics
#   MALOKINIS, Ioannis              3      3  Athens     1896       Aquatics
#   CHASAPIS, Spiridon              4      4  Athens     1896       Aquatics
#   ...                           ...    ...     ...      ...            ...
#   JENSEN, Viggo                 146    146  Athens     1896  Weightlifting
#   ELLIOTT, Launceston           147    147  Athens     1896  Weightlifting
#   CHRISTOPOULOS, Stephanos      148    148  Athens     1896      Wrestling
#   SCHUMANN, Carl                149    149  Athens     1896      Wrestling
#   TSITAS, Georgios              150    150  Athens     1896      Wrestling
#
# ...

# %%
for group_key,group_value in oo.groupby('Edition'):
    print(group_key) #print行必须缩进
    print(group_value)
# Out:
# 1896
#                           level_0  index    City  Edition          Sport  \
# Athlete
# HAJOS, Alfred                   0      0  Athens     1896       Aquatics
# HERSCHMANN, Otto                1      1  Athens     1896       Aquatics
# DRIVAS, Dimitrios               2      2  Athens     1896       Aquatics
# MALOKINIS, Ioannis              3      3  Athens     1896       Aquatics
# CHASAPIS, Spiridon              4      4  Athens     1896       Aquatics
# ...                           ...    ...     ...      ...            ...
# JENSEN, Viggo                 146    146  Athens     1896  Weightlifting
# ELLIOTT, Launceston           147    147  Athens     1896  Weightlifting
# CHRISTOPOULOS, Stephanos      148    148  Athens     1896      Wrestling
# SCHUMANN, Carl                149    149  Athens     1896      Wrestling
# TSITAS, Georgios              150    150  Athens     1896      Wrestling
#
#                                Discipline  NOC Gender  \
# Athlete
# ...

# %%
oo.groupby('Edition').size()
# Out:
# Edition
# 1896     151
# 1900     512
# 1904     470
# 1908     804
# 1912     885
# 1920    1298
# 1924     884
# 1928     710
# 1932     615
# 1936     875
# 1948     814
# 1952     889
# 1956     885
# 1960     882
# 1964    1010
# 1968    1031
# 1972    1185
# 1976    1305
# 1980    1387
# 1984    1459
# 1988    1546
# 1992    1705
# 1996    1859
# 2000    2015
# 2004    1998
# 2008    2042
# dtype: int64

# %%
oo.groupby(['Edition','NOC','Medal']).agg(['min','max','count'])
# Out:
#                    level_0               index                  City           \
#                        min    max count    min    max count      min      max
# Edition NOC Medal
# 1896    AUS Gold        18     24     2     18     24     2   Athens   Athens
#         AUT Bronze      53     58     2     53     58     2   Athens   Athens
#             Gold         9     56     2      9     56     2   Athens   Athens
#             Silver       1      1     1      1      1     1   Athens   Athens
#         DEN Bronze      69    129     3     69    129     3   Athens   Athens
# ...                    ...    ...   ...    ...    ...   ...      ...      ...
# 2008    UZB Silver   28597  29176     2  28597  29176     2  Beijing  Beijing
#         VEN Bronze   28960  28960     1  28960  28960     1  Beijing  Beijing
#         VIE Silver   29102  29102     1  29102  29102     1  Beijing  Beijing
#         ZIM Gold     27243  27243     1  27243  27243     1  Beijing  Beijing
# ...

# %%
oo.groupby(['Edition','NOC','Medal']).agg('count')
# Out:
#                     level_0  index  City  Sport  Discipline  Gender  Event  \
# Edition NOC Medal
# 1896    AUS Gold          2      2     2      2           2       2      2
#         AUT Bronze        2      2     2      2           2       2      2
#             Gold          2      2     2      2           2       2      2
#             Silver        1      1     1      1           1       1      1
#         DEN Bronze        3      3     3      3           3       3      3
# ...                     ...    ...   ...    ...         ...     ...    ...
# 2008    UZB Silver        2      2     2      2           2       2      2
#         VEN Bronze        1      1     1      1           1       1      1
#         VIE Silver        1      1     1      1           1       1      1
#         ZIM Gold          1      1     1      1           1       1      1
#             Silver        3      3     3      3           3       3      3
#
#                     Event_gender
# ...

# %%
oo.groupby(['Edition','NOC','Medal']).size()
# Out:
# Edition  NOC  Medal
# 1896     AUS  Gold      2
#          AUT  Bronze    2
#               Gold      2
#               Silver    1
#          DEN  Bronze    3
#                        ..
# 2008     UZB  Silver    2
#          VEN  Bronze    1
#          VIE  Silver    1
#          ZIM  Gold      1
#               Silver    3
# Length: 2356, dtype: int64

# %%
oo.groupby(['Edition','NOC','Medal']).agg({'Edition':['min','max','count']})
# Out:
#                    Edition
#                        min   max count
# Edition NOC Medal
# 1896    AUS Gold      1896  1896     2
#         AUT Bronze    1896  1896     2
#             Gold      1896  1896     2
#             Silver    1896  1896     1
#         DEN Bronze    1896  1896     3
# ...                    ...   ...   ...
# 2008    UZB Silver    2008  2008     2
#         VEN Bronze    2008  2008     1
#         VIE Silver    2008  2008     1
#         ZIM Gold      2008  2008     1
#             Silver    2008  2008     3
#
# [2356 rows x 3 columns]

# %%
import pandas as pd

# %%
oo=pd.read_csv('C:/Users/may/Desktop/data/olympics.csv', skiprows=4)

# %%
oo.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
oo.Athlete=="LEWIS,Carl"
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 29211    False
# 29212    False
# 29213    False
# 29214    False
# 29215    False
# Name: Athlete, Length: 29216, dtype: bool

# %%
oo[oo.Athlete=='LEWIS, Carl'].groupby('Athlete').agg({'Edition':['min','max','count']})
# Out:
#             Edition
#                 min   max count
# Athlete
# LEWIS, Carl    1984  1996    10

# %%
oo.groupby('Edition').size().plot()
# Out:
# <AxesSubplot:xlabel='Edition'>

# %%
oo.groupby('NOC').agg({"Edition":['count','min','max']})
# Out:
#     Edition
#       count   min   max
# NOC
# AFG       1  2008  2008
# AHO       1  1988  1988
# ALG      14  1984  2008
# ANZ      29  1908  1912
# ARG     239  1924  2008
# ..      ...   ...   ...
# VIE       2  2000  2008
# YUG     435  1924  2000
# ZAM       2  1984  1996
# ZIM      23  1980  2008
# ZZX      48  1896  1904
#
# [138 rows x 3 columns]

# %%
sub=oo[(oo.Edition==2008) & ((oo.Event=='100m')|(oo.Event=='200m'))]
sub
# Out:
#           City  Edition      Sport Discipline                   Athlete  NOC  \
# 27551  Beijing     2008  Athletics  Athletics               DIX, Walter  USA
# 27552  Beijing     2008  Athletics  Athletics               BOLT, Usain  JAM
# 27553  Beijing     2008  Athletics  Athletics         THOMPSON, Richard  TRI
# 27554  Beijing     2008  Athletics  Athletics        FRASER, Shelly-ann  JAM
# 27555  Beijing     2008  Athletics  Athletics          SIMPSON, Sherone  JAM
# 27556  Beijing     2008  Athletics  Athletics           STEWART, Kerron  JAM
# 27569  Beijing     2008  Athletics  Athletics               DIX, Walter  USA
# 27570  Beijing     2008  Athletics  Athletics               BOLT, Usain  JAM
# 27571  Beijing     2008  Athletics  Athletics           CRAWFORD, Shawn  USA
# 27572  Beijing     2008  Athletics  Athletics           STEWART, Kerron  JAM
# 27573  Beijing     2008  Athletics  Athletics  CAMPBELL-BROWN, Veronica  JAM
# ...

# %%
g=sub.groupby(['NOC','Gender','Discipline','Event']).size()

# %%
g.unstack(['Discipline','Event'])
# Out:
# Discipline Athletics
# Event           100m 200m
# NOC Gender
# JAM Men          1.0  1.0
#     Women        3.0  2.0
# TRI Men          1.0  NaN
# USA Men          1.0  2.0
#     Women        NaN  1.0

# %%
g.head()
# Out:
# NOC  Gender  Discipline  Event
# JAM  Men     Athletics   100m     1
#                          200m     1
#      Women   Athletics   100m     3
#                          200m     2
# TRI  Men     Athletics   100m     1
# dtype: int64

# %%
g.unstack()
# Out:
# Event                  100m  200m
# NOC Gender Discipline
# JAM Men    Athletics    1.0   1.0
#     Women  Athletics    3.0   2.0
# TRI Men    Athletics    1.0   NaN
# USA Men    Athletics    1.0   2.0
#     Women  Athletics    NaN   1.0

# %%
g.head()
# Out:
# NOC  Gender  Discipline  Event
# JAM  Men     Athletics   100m     1
#                          200m     1
#      Women   Athletics   100m     3
#                          200m     2
# TRI  Men     Athletics   100m     1
# dtype: int64

# %%
usgold=oo[(oo.NOC=="USA")&(oo.Medal=="Gold")]
usgold
# Out:
#           City  Edition       Sport       Discipline           Athlete  NOC  \
# 13      Athens     1896   Athletics        Athletics     BURKE, Thomas  USA
# 15      Athens     1896   Athletics        Athletics    CURTIS, Thomas  USA
# 21      Athens     1896   Athletics        Athletics     BURKE, Thomas  USA
# 27      Athens     1896   Athletics        Athletics   GARRETT, Robert  USA
# 29      Athens     1896   Athletics        Athletics     CLARK, Ellery  USA
# ...        ...      ...         ...              ...               ...  ...
# 29048  Beijing     2008  Volleyball       Volleyball      ROONEY, Sean  USA
# 29049  Beijing     2008  Volleyball       Volleyball     SALMON, Riley  USA
# 29050  Beijing     2008  Volleyball       Volleyball  STANLEY, Clayton  USA
# 29051  Beijing     2008  Volleyball       Volleyball  TOUZINSKY, Scott  USA
# 29151  Beijing     2008   Wrestling  Wrestling Free.     CEJUDO, Henry  USA
#
#       Gender         Event Event_gender Medal
# ...

# %%
usgold.groupby(['Edition','Gender']).size()
# Out:
# Edition  Gender
# 1896     Men        11
# 1900     Men        26
#          Women       1
# 1904     Men       140
#          Women       6
# 1908     Men        34
# 1912     Men        45
# 1920     Men       103
#          Women       7
# 1924     Men        95
#          Women      15
# 1928     Men        34
#          Women       9
# 1932     Men        61
#          Women      17
# 1936     Men        44
#          Women       7
# 1948     Men        75
#          Women       8
# 1952     Men        72
#          Women       7
# 1956     Men        57
#          Women       4
# 1960     Men        51
#          Women      17
# 1964     Men        63
#          Women      15
# 1968     Men        59
#          Women      24
# 1972     Men        37
#          Women      16
# 1976     Men        56
#          Women       7
# 1984     Men       106
#          Women      62
# 1988     Men        49
#          Women      28
# 1992     Men        57
#          Women      32
# ...

# %%
usgold.groupby(['Edition','Gender']).size().unstack('Gender',fill_value=0)
# Out:
# Gender   Men  Women
# Edition
# 1896      11      0
# 1900      26      1
# 1904     140      6
# 1908      34      0
# 1912      45      0
# 1920     103      7
# 1924      95     15
# 1928      34      9
# 1932      61     17
# 1936      44      7
# 1948      75      8
# 1952      72      7
# 1956      57      4
# 1960      51     17
# 1964      63     15
# 1968      59     24
# 1972      37     16
# 1976      56      7
# 1984     106     62
# 1988      49     28
# 1992      57     32
# 1996      59    101
# 2000      68     62
# 2004      51     65
# 2008      67     58

# %%
result=oo.groupby(['Athlete','Medal']).size().unstack('Medal',fill_value=0)

# %%
result
# Out:
# Medal                      Bronze  Gold  Silver
# Athlete
# AABYE, Edgar                    0     1       0
# AALTONEN, Arvo Ossian           2     0       0
# AALTONEN, Paavo Johannes        2     3       0
# AAMODT, Ragnhild                0     1       0
# AANING, Alf Lied                0     0       1
# ...                           ...   ...     ...
# ÖSTERVOLD, Jan Olsen            0     1       0
# ÖSTERVOLD, Kristian Olsen       0     1       0
# ÖSTERVOLD, Ole Olsen            0     1       0
# ÖSTMO, Ole                      2     0       2
# ÖSTRAND, Per-Olof               1     0       0
#
# [21413 rows x 3 columns]

# %%
result.sort_values(['Gold','Silver','Bronze'],ascending=False)[['Gold','Silver','Bronze']]
# Out:
# Medal                Gold  Silver  Bronze
# Athlete
# PHELPS, Michael        14       0       2
# LATYNINA, Larisa        9       5       4
# NURMI, Paavo            9       3       0
# SPITZ, Mark             9       1       1
# LEWIS, Carl             9       1       0
# ...                   ...     ...     ...
# ZYCH, Boguslaw          0       0       1
# ZÄHRINGER, Klaus        0       0       1
# ZÜHLKE, Steffen         0       0       1
# ÖRSTED, Hans-Henrik     0       0       1
# ÖSTRAND, Per-Olof       0       0       1
#
# [21413 rows x 3 columns]

# %%
result.sort_values(['Gold','Silver','Bronze'],ascending=False)[['Gold','Silver','Bronze']].head(10)
# Out:
# Medal             Gold  Silver  Bronze
# Athlete
# PHELPS, Michael     14       0       2
# LATYNINA, Larisa     9       5       4
# NURMI, Paavo         9       3       0
# SPITZ, Mark          9       1       1
# LEWIS, Carl          9       1       0
# FISCHER, Birgit      8       4       0
# KATO, Sawao          8       3       1
# THOMPSON, Jenny      8       3       1
# BIONDI, Matthew      8       2       1
# EWRY, Ray            8       0       0

# %%
result.sort_values(['Gold','Silver','Bronze'],ascending=False)[['Gold','Silver','Bronze']].head(10).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Athlete'>
